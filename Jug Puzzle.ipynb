# %%
# JUG PUZZLE GAME

def fill_water(jug,capacity):
    jug=capacity
    return jug
    

    
def empty(jug,capacity):
    jug=0
    return jug



def transfer(jug_1,capacity_1,jug_2,capacity_2):
    temp=0
    if jug_2>=capacity_2:
        print("Jug 2 is already Full")
    elif jug_1<=0:
        print("Jug1 is empty")
        
    else:
        temp=capacity_2-jug_2

        if jug_1<temp:
            temp=jug_1
        jug_1-=temp
        jug_2+=temp
#         print("temp",temp,"JUG_2 initial=",jug_2,end="   ")
#         print("JUG_1",jug_1,"JUG_2",jug2)
    return (jug_1,jug_2)



jug1=0
jug2=0

capacity1=3
capacity2=5

curr_jug=jug1

required=4
moves=0
stop=True




while True:
    jug_choose=int(input("Enter Jug number"))
    action=input("Enter the action")
    
    if jug_choose==1:
        if action=="fill":
            jug1=fill_water(jug1,capacity1)
        elif action=="empty":
            jug1=empty(jug1,capacity1)
        elif action=="transfer":
            print("Water is Transferred from jug1 to jug2")
            jug1,jug2=transfer(jug1,capacity1,jug2,capacity2)
    
    else:
        if action=="fill":
            jug2=fill_water(jug2,capacity2)
        elif action=="empty":
            jug2=empty(jug2,capacity2)
        elif action=="transfer":
            print("Water is Transferred from jug2 to jug1")
            jug2,jug1=transfer(jug2,capacity2,jug1,capacity1)
            
    
    
    print("Water in JUG1=",jug1,"Water in JUG2=",jug2)
    print("**"*10)
    if jug1==required or jug2==required:
        print("YOU DID IT IN ",moves,"MOVES")
        break
    moves=moves+1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 51
#      45 stop=True
#      50 while True:
# ---> 51     jug_choose=int(input("Enter Jug number"))
#      52     action=input("Enter the action")
#      54     if jug_choose==1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# ...

# %%
##Using AI to solve this:
# Assumption Jug1>Jug2

n=int(input("Enter Capacity of Larger JUG "))
m=int(input("Enter Capacity of smaller JUG "))

jug1=0
jug2=0

capacity1=n
capacity2=m


target=int(input("Enter the target "))  

if target%gcd(n,m)!=0:
    print("Not possible to get ",target,"L of water using ",n,m)
else:
# Out:
#   Cell In[2], line 18
#     else:
#          ^
# SyntaxError: incomplete input

# %%
def gcd(a,b):
    if b==0:
        return a
    return gcd(b,a%b)

# %%
print(gcd(5,3))
# Out:
# 1

# %%
##Using AI to solve this:
# Assumption Jug1>Jug2


def fill_water(jug,capacity):
    jug=capacity
    return jug
    

    
def empty(jug,capacity):
    jug=0
    return jug



def transfer(jug_1,capacity_1,jug_2,capacity_2):
    temp=0
    if jug_2>=capacity_2:
        print("Jug 2 is already Full")
    elif jug_1<=0:
        print("Jug1 is empty")
        
    else:
        temp=capacity_2-jug_2

        if jug_1<temp:
            temp=jug_1
        jug_1-=temp
        jug_2+=temp
#         print("temp",temp,"JUG_2 initial=",jug_2,end="   ")
#         print("JUG_1",jug_1,"JUG_2",jug2)
    return (jug_1,jug_2)


n=int(input("Enter Capacity of Larger JUG "))
m=int(input("Enter Capacity of smaller JUG "))

jug1=0
jug2=0

capacity1=n
capacity2=m


target=int(input("Enter the target "))  

if target%gcd(n,m)!=0:
    print("Not possible to get ",target,"L of water using containers of ",n,"L and ",m,"L Jug")
else:

    while True:

        print("Water in JUG1=",jug1,"Water in JUG2=",jug2)
        print("**"*10)
        if jug1==target or jug2==target:
            print("WINN!!!!!!!!!!!!!!!!",jug1,jug2)
            break

        jug1=fill_water(jug1,n)
        print("Fill water in jug1")
        print("Water in JUG1=",jug1,"Water in JUG2=",jug2)
        print("**"*10)

        if jug1==target or jug2==target:
            print("WINN!!!!!!!!!!",jug1,jug2)
            break

        jug1,jug2=transfer(jug1,capacity1,jug2,capacity2)
        print("Transfer Water from jug1 to jug2")
        print("Water in JUG1=",jug1,"Water in JUG2=",jug2)
        print("**"*10)
        if jug1==target or jug2==target:
            print("WINN!!!!!!!!!!",jug1,jug2)
            break

        jug2=empty(jug2,capacity2)
        print("Empty water from jug2")
        print("Water in JUG1=",jug1,"Water in JUG2=",jug2)
        print("**"*10)

        if jug1==target or jug2==target:
            print("WINN!!!!!!!!!!",jug1,jug2)
            break

        jug1,jug2=transfer(jug1,capacity1,jug2,capacity2)
        if jug1==target or jug2==target:
            print("WINN!!!!!!!!!!!!!!!!",jug1,jug2)
            break
# Out:
# Enter Capacity of Larger JUG 7
# Enter Capacity of smaller JUG 5
# Enter the target 3
# Water in JUG1= 0 Water in JUG2= 0
# ********************
# Fill water in jug1
# Water in JUG1= 7 Water in JUG2= 0
# ********************
# Transfer Water from jug1 to jug2
# Water in JUG1= 2 Water in JUG2= 5
# ********************
# Empty water from jug2
# Water in JUG1= 2 Water in JUG2= 0
# ********************
# Water in JUG1= 0 Water in JUG2= 2
# ********************
# Fill water in jug1
# Water in JUG1= 7 Water in JUG2= 2
# ********************
# Transfer Water from jug1 to jug2
# Water in JUG1= 4 Water in JUG2= 5
# ********************
# Empty water from jug2
# Water in JUG1= 4 Water in JUG2= 0
# ********************
# Water in JUG1= 0 Water in JUG2= 4
# ********************
# Fill water in jug1
# Water in JUG1= 7 Water in JUG2= 4
# ********************
# Transfer Water from jug1 to jug2
# Water in JUG1= 6 Water in JUG2= 5
# ********************
# Empty water from jug2
# ...
