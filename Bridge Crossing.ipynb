# %%
bridge=""
time=30

people={"A":1,"B":2,"C":3,"D":8,"E":12}
l=[]
r=["A","B","C","D","E"]

print(l,"BRIDGE",r,"           TIME",time)

while time>0:
    
    temp=0
    while temp<=0:
        p1=input("Enter first person to cross the bridge")
        if p1 not in r:
            print(p1," is on other side ")
#             p1=input("Enter first person to cross the bridge")
        else:
            r.remove(p1)
            temp=1
            p2=input("Enter second person to cross the bridge")
            if p2 not in r:
                print(p2," is on other side ")
                p2=input("Enter second person to cross the bridge")
                temp*=0
            else:
                temp*=1
    print("Crossed Once")
        
    curr_time=max(people[p1],people[p2])
    time-=curr_time
    
    r.remove(p2)
    
    l.append(p1)
    l.append(p2)
    
    if len(l)==5 and len(r)==0:
        print("WIN!!!")
        break
    
    print(l,"BRIDGE",r,"           TIME",time)
    
    
    temp=0
    while temp<=0:
        p=input("Enter person to return with lamp")
        if p1 not in l:
            print(p1," is on other side ")
            p=input("Enter person to return with lamp")
        else:
            temp=1
    time-=people[p]
    
    l.remove(p)
    r.append(p)
    print(l,"BRIDGE",r,"           TIME",time)
    
    
if time<=0:
    print("You Loose Try again")
# Out:
# [] BRIDGE ['A', 'B', 'C', 'D', 'E']            TIME 30
# Enter first person to cross the bridgeA
# Enter second person to cross the bridgeA
# A  is on other side
# Enter second person to cross the bridgeB
# Enter first person to cross the bridgeA
# A  is on other side
# Enter first person to cross the bridgeC
# Enter second person to cross the bridgeD
# Crossed Once
# ['C', 'D'] BRIDGE ['B', 'E']            TIME 22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 47
#      45 temp=0
#      46 while temp<=0:
# ---> 47     p=input("Enter person to return with lamp")
#      48     if p1 not in l:
#      49         print(p1," is on other side ")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
# ...

# %%
def take_input(l,r):
    p=input("Enter Person ")
    return p
    





bridge=""
time=30

people={"A":1,"B":3,"C":6,"D":8,"E":12}
l=[]
r=["A","B","C","D","E"]

print(l,"BRIDGE",r,"           TIME",time)

while time>0:
    
    p1=take_input(l,r)
    bool1=True
    while bool1:
        if p1 in r:
            r.remove(p1)
            l.append(p1)
            bool1=False
            t1=people[p1]
            
            print("t1=",people[p1],end=" ")
            
            bool2=True
            p2=take_input(l,r)
            while bool2:
                if p2 in r:
                    r.remove(p2)
                    l.append(p2)
                    bool2=False
                    t2=people[p2]
                    print("t2=",people[p2],end=" ")
                    break
                else:
                    print("Invalid input enter from the people on right ")
                    p2=take_input(l,r)
                    t2=0
                print("BOOL2",bool2)
        else:
            print("Invalid input enter from the people on right ")
            p1=take_input(l,r)
            t1=0
        print("BOOL1",bool1)
    
    print(t1,t2,max(t1,t2))
    time-=max(t1,t2)
    
    print(l,"  BRIDGE  ",r,"     TIME=",time)
    
    if len(r)==0 and len(l)==len(people.keys()) and time>0:
        print("WIN")
        break
    
    
    #RETURN
    
    bool3=True
    p=take_input(l,r)
    while bool3:
        if p in l:
            l.remove(p)
            r.append(p)
            bool3=False
            break
            t=people[p]
        else:
            print("Invalid input enter from the people on right ")
            p=take_input(l,r)
            t=0
    time-=t
    print(l,"  BRIDGE  ",r,"     TIME=",time)
    
if time<=0:
    print("You Loose Try again")
# Out:
# [] BRIDGE ['A', 'B', 'C', 'D', 'E']            TIME 30
# Enter Person A
# t1= 1 Enter Person B
# t2= 3 BOOL1 False
# 1 3 3
# ['A', 'B']   BRIDGE   ['C', 'D', 'E']      TIME= 27
# Enter Person E
# Invalid input enter from the people on right
# Enter Person B
# ['A']   BRIDGE   ['C', 'D', 'E', 'B']      TIME= 27
# Enter Person E
# t1= 12 Enter Person B
# t2= 3 BOOL1 False
# 12 3 12
# ['A', 'E', 'B']   BRIDGE   ['C', 'D']      TIME= 15
# Enter Person D
# Invalid input enter from the people on right
# Enter Person E
# ['A', 'B']   BRIDGE   ['C', 'D', 'E']      TIME= 15
# Enter Person C
# t1= 6 Enter Person E
# t2= 12 BOOL1 False
# 6 12 12
# ['A', 'B', 'C', 'E']   BRIDGE   ['D']      TIME= 3
# Enter Person A
# ['B', 'C', 'E']   BRIDGE   ['D', 'A']      TIME= 3
# Enter Person D
# t1= 8 Enter Person A
# t2= 1 BOOL1 False
# 8 1 8
# ['B', 'C', 'E', 'D', 'A']   BRIDGE   []      TIME= -5
# Enter Person A
# ['B', 'C', 'E', 'D']   BRIDGE   ['A']      TIME= -5
# You Loose Try again

# %%
print("\U0001F3C3","\U0001F6B6","\U0001F6B6\u200D\u2640\uFE0F","\U0001F3C3\U0001F3FB\u200D\u2640\uFE0F","\U0001F469\U0001F3FC\u200D\U0001F9AF")
# Out:
# 🏃 🚶 🚶‍♀️ 🏃🏻‍♀️ 👩🏼‍🦯

# %%
def take_input(l,r):
    p=input("Enter Person ")
    return p
    

bridge=""
time=30

people={"A":1,"B":3,"C":6,"D":8,"E":12}
l=[]
r=["A","B","C","D","E"]

print(l,"BRIDGE",r,"           TIME",time)

while time>0:
    
    p1=take_input(l,r)
    bool1=True
    while bool1:
        if len(r)==0 and len(l)==len(people.keys()) and time>0:
            print("WIN")
            break
        if p1 in r:
            r.remove(p1)
            l.append(p1)
            bool1=False
            t1=people[p1]
                       
            bool2=True
            p2=take_input(l,r)
            while bool2:
                if p2 in r:
                    r.remove(p2)
                    l.append(p2)
                    bool2=False
                    t2=people[p2]
                    break
                else:
                    print("Invalid input enter from the people on right ")
                    p2=take_input(l,r)
                    t2=0
        else:
            print("Invalid input enter from the people on right ")
            p1=take_input(l,r)
            t1=0
    
    print(t1,t2,max(t1,t2))
    time-=max(t1,t2)
    
    print(l,"  BRIDGE  ",r,"     TIME=",time)
    
    if len(r)==0 and len(l)==len(people.keys()) and time>0:
        print("WIN")
        break
    
    
    #RETURN
    
    bool3=True
    
    print("RETURN: ",end=" ")
    p=take_input(l,r)
    while bool3:
        if p in l:
            l.remove(p)
            r.append(p)
            bool3=False
            break
            t=people[p]
        else:
            print("Invalid input ","enter from the people on left only ")
            p=take_input(l,r)
            t=0
    time-=t
    print(l,"  BRIDGE  ",r,"     TIME=",time)
    
if time<=0:
    print("You Loose Try again")
# Out:
# [] BRIDGE ['A', 'B', 'C', 'D', 'E']            TIME 30
# Enter Person A
# Enter Person B
# 1 3 3
# ['A', 'B']   BRIDGE   ['C', 'D', 'E']      TIME= 27
# RETURN:  Enter Person B
# ['A']   BRIDGE   ['C', 'D', 'E', 'B']      TIME= 27
# Enter Person C
# Enter Person A
# Invalid input enter from the people on right
# Enter Person C
# Invalid input enter from the people on right
# Enter Person D
# 6 8 8
# ['A', 'C', 'D']   BRIDGE   ['E', 'B']      TIME= 19
# RETURN:  Enter Person A
# ['C', 'D']   BRIDGE   ['E', 'B', 'A']      TIME= 19
# Enter Person E
# Enter Person A
# 12 1 12
# ['C', 'D', 'E', 'A']   BRIDGE   ['B']      TIME= 7
# RETURN:  Enter Person A
# ['C', 'D', 'E']   BRIDGE   ['B', 'A']      TIME= 7
# Enter Person A
# Enter Person B
# 1 3 3
# ['C', 'D', 'E', 'A', 'B']   BRIDGE   []      TIME= 4
# WIN

# %%
#Solving using Algorithm For any Question 
def take_input(l,r):
    p=input("Enter Person ")
    return p
    
def get_min(arr):
#     print("L in step 4 ",l)
    mini_time=list(arr.values())[0]
    mini_person=list(arr.keys())[0]
    for n,t in arr.items():
        if t<mini_time:
            mini_person=n
            mini_time=t
    return mini_person

    
bridge=""
time=0

# people={}
# n_people=int(input("Enter total number of people "))
# for i in range(n_people):
#     name=input("Enter name of Person:")
#     speed=int(input("Enter the time required for person to cross the Bridge "))
    
#     people[name]=speed


# people={"A":1,"B":3,"D":8,"C":6,"E":12}
# people={"Adam":1, "Bob":2, "Clair":5,"Dave":10}
people={"A":1, "B":2, "C":5,"D":8}
print("PEOPLE and SPEED : ",people)


sorted_people=dict(sorted(people.items(), key=lambda item: item[1]))
l={}
r=sorted_people.copy()
print("Sorted = ",sorted_people)
print("\n",list(l.keys()),"BRIDGE",list(r.keys()),"           TIME",time)

    
t1=0
t2=0
while True:
    #Step1: Send two Fastest People to left side
    if len(r.keys())>=1:
        p1=list(r.keys())[0]
        t1=sorted_people[p1]
        del  r[p1]
        l[p1]=sorted_people[str(p1)]
    
    
        if len(r.keys())>=1:
            p2=list(r.keys())[0]
            l[p2]=sorted_people[p2]
            t2=sorted_people[p2]
            del  r[p2]
        else:
            print("Noone Left")
    else:
        print("Noone Left")
        break
        
    
    time+=max(t1,t2)
    print("Take ",p1," and ",p2," to left side ")
    print("\n",list(l.keys()),"BRIDGE",list(r.keys()),"           TIME",time)
    
    if l==sorted_people:
        print("Win!!!")
        break
    
    #Step2: Send the Fastest among the two on Left back to the right
    if len(l.keys())>=1:
        p=get_min(l)
        del l[p]
        r[p]=sorted_people[p]
        time+=sorted_people[p]
    else:
        print("Noone Left")
    
    print("Take ",p," from left to right side ")
    print("\n",list(l.keys()),"BRIDGE",list(r.keys()),"           TIME",time)
    if l==sorted_people:
        print("Win!!!")
        break

    #Step3: Send the slowest among the right to the left
    
    if len(r.keys())>=1:
        r=dict(sorted(r.items(),key=lambda item:item[1]))
        p1=list(r.keys())[-1]
        t1=sorted_people[p1]
        l[p1]=sorted_people[str(p1)]
        del  r[p1]
    
        if len(r.keys())>=1:
            p2=list(r.keys())[-1]
            t2=sorted_people[p2]
            l[p2]=sorted_people[p2]
            del  r[p2]
        else:
            print("Noone Left")
            
    else:
        print("Noone Left")
        break

    time+=max(t1,t2)
    print("Take ",p1," and ",p2," to left side ")
    print("\n",list(l.keys()),"BRIDGE",list(r.keys()),"           TIME",time)
    if l==sorted_people:
        print("Win!!!")
        break
        
    
    #Step4: Send the Fastest among the Left back to the right
    if len(l.keys())>=1:
        p=get_min(l)
        del l[p]
        r[p]=sorted_people[p]
        time+=sorted_people[p]
    else:
        print("Noone Left")
    
    print("Take ",p," from left to right side ")
    print("\n",list(l.keys()),"BRIDGE",list(r.keys()),"           TIME",time)
    if l==sorted_people:
        print("Win!!!")
        break
# Out:
# PEOPLE and SPEED :  {'A': 1, 'B': 2, 'C': 5, 'D': 8}
# Sorted =  {'A': 1, 'B': 2, 'C': 5, 'D': 8}
#
#  [] BRIDGE ['A', 'B', 'C', 'D']            TIME 0
# Take  A  and  B  to left side
#
#  ['A', 'B'] BRIDGE ['C', 'D']            TIME 2
# Take  A  from left to right side
#
#  ['B'] BRIDGE ['C', 'D', 'A']            TIME 3
# Take  D  and  C  to left side
#
#  ['B', 'D', 'C'] BRIDGE ['A']            TIME 11
# Take  B  from left to right side
#
#  ['D', 'C'] BRIDGE ['A', 'B']            TIME 13
# Take  A  and  B  to left side
#
#  ['D', 'C', 'A', 'B'] BRIDGE []            TIME 15
# Win!!!
